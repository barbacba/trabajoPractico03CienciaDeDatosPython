# %% [markdown]
# <a href="https://colab.research.google.com/github/barbacba/trabajoPractico03CienciaDeDatosPython/blob/main/PRACTICO3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TRABAJO PRACTICO N 3

# %% [markdown]
# ***TEMAS A DESARROLLAR:***
#
# Nociones de Probabilidad, simulación de procesos aleatorios, cálculo de parámetros estadisticos: Media o Valor Esperado(PROMEDIO), Mediana, Desvio Estandar. DISTRIBUCIONES DE PROABABILIDAD más frecuentes, por ejemplo la Normal.

# %% [markdown]
# ## Funciones estadísticas para análisis exploratorio de datos
# A continuación se presentan ejemplos de funciones estadísticas para el análisis exploratorio de datos utilizando NumPy:

# %% [markdown]
# #### Crear array aleatorio
# En esta celda, se utiliza la función np.random.rand() de NumPy para crear un array de números aleatorios con una forma específica. Luego, se imprime el array.

# %%
import numpy as np
random_array = np.random.randint(0,10, (4,3))
print("Array aleatorio:", random_array)
# Out:
# Array aleatorio: [[8 4 6]
#  [3 8 5]
#  [2 6 3]
#  [0 5 6]]

# %% [markdown]
# #### Media
# En esta celda, se crea un array 'array' y se utiliza la función np.mean() de NumPy para calcular la media del array. Luego, se imprime el resultado.

# %%
array = np.array([1, 2, 3, 4, 5])
media = np.mean(array)
print("Media:", media)
# Out:
# Media: 3.0

# %% [markdown]
# #### Desviación estándar
# En esta celda, se crea un array 'array' y se utiliza la función np.std() de NumPy para calcular la desviación estándar del array. Luego, se imprime el resultado.

# %%
array = np.array([1, 2, 3, 4, 5])
desviacion_estandar = np.std(array)
print("Desviación estándar:", desviacion_estandar)
# Out:
# Desviación estándar: 1.4142135623730951

# %% [markdown]
# #### Varianza
# La función np.var() se utiliza para calcular la varianza de un array.
# Ejemplo de uso:

# %%
array = np.array([1, 2, 3, 4, 5])
varianza = np.var(array)
print("Varianza:", varianza)
# Out:
# Varianza: 2.0

# %% [markdown]
# #### Valor mínimo
# En esta celda, se crea un array 'array' y se utiliza la función np.min() de NumPy para encontrar el valor mínimo del array. Luego, se imprime el resultado.

# %%
array = np.array([1, 2, 3, 4, 5])
matriz=np.random.randint(-3,3,(5,5))
#minimo = np.min(array)
minimo = np.min(matriz, axis=0)
print("Valor mínimo:", minimo)
print( matriz)
# Out:
# Valor mínimo: [-1 -3 -2 -1 -3]
# [[ 2 -1  2  0 -1]
#  [-1 -3 -2  1 -3]
#  [ 1  1 -1 -1 -1]
#  [ 0  2  1 -1  2]
#  [ 1  1  0  0  2]]

# %% [markdown]
# #### Valor máximo
# En esta celda, se crea un array 'array' y se utiliza la función np.max() de NumPy para encontrar el valor máximo del array. Luego, se imprime el resultado.

# %%
maximo = np.max(array)
print("Valor máximo:", maximo)
# Out:
# Valor máximo: 5

# %% [markdown]
# #### Gráfico de dispersión
# En esta celda, se crea un array 'x' con valores aleatorios y un array 'y' con valores aleatorios. Luego, se utiliza la biblioteca Matplotlib para trazar un gráfico de dispersión con 'x' en el eje x y 'y' en el eje y. También se agrega etiquetas y un título al gráfico.

# %%
import matplotlib.pyplot as plt
x = np.random.rand(100)
y = np.random.rand(100)

plt.scatter(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Gráfico de dispersión')
plt.show()

# %% [markdown]
# En esta celda, se crea un array 'data' con valores aleatorios siguiendo una distribución normal. Luego, se utiliza la biblioteca Matplotlib para trazar un histograma de 'data'. También se agrega etiquetas y un título al gráfico.

# %%
data = np.random.normal(0, 1, 1000)

plt.hist(data, bins=30)
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title('Histograma')
plt.show()

# %% [markdown]
# #### Mediana
# La función np.median() se utiliza para calcular la mediana de un array.
# Ejemplo de uso:

# %%
array = np.array([1, 2, 3, 4, 5])
mediana = np.median(array)
print("Mediana:", mediana)
# Out:
# Mediana: 3.0

# %% [markdown]
# #### Percentiles
# La función np.percentile() se utiliza para calcular los percentiles de un array.
# Ejemplo de uso:

# %%
array = np.array([1, 2, 3, 4, 5])
percentil_50 = np.percentile(array, 50)
print("Percentil 50:", percentil_50)
# Out:
# Percentil 50: 3.0

# %% [markdown]
# # EJEMPLOS Y APLICACIÓNES

# %% [markdown]
# ***APLICACIÓN DE PROBABILIDAD***
#
# Se Realiza el lanzamiento de un dado EQUILIBRADO JUSTO, de manera reiterada con las mismas condiciones, y se anotan sus resultados= CARA O CRUZ.
#
# Se le pide al usuario que defina la cantidad N de lanzamientos y se calcula su frecuencia relativa= 'PROBABILIDAD' de obtener cara o cruz. Se obtiene los siguientes resultados:

# %%
import numpy as np
n=int(input('ingrese la cantidad de simulación o lanzamientos: '))

#========= FORMA 1 DE SIMULAR LANZAMIENTO DE UN DADO============
dado=[]
n_cara=0
n_cruz=0
cara_o_cruz_str=""
for i in range(n):
  dado.append(np.random.rand(1))
  dado1=np.array(dado)
  if dado1[i]<0.5:
    cara_o_cruz_str= cara_o_cruz_str + 'O'
    #print(dado[i])
    n_cara +=1
  else:
    cara_o_cruz_str= cara_o_cruz_str + 'X'
    #print(dado[i])
    n_cruz +=1
print("O es cara y X cruz")
print(cara_o_cruz_str)
print(f"Salieron {n_cara} veces cara y {n_cruz} veces cruz")
# Out:
# ingrese la cantidad de simulación o lanzamientos: 100
# O es cara y X cruz
# XOXOXOOXOOOXXOOXOOXXXOXOOXXXOXXOXOXOOXOXXXOXOXXOXOOOOOOXXXOXOOOOXXXXXXOXOOOOXOOOXXXOOOXXOOXOOOXOXXOX
# Salieron 52 veces cara y 48 veces cruz

# %%
#  mostrar la probailidad frecuencista de el lanzamiento de un dado
prom_cara=n_cara/n
prom_cruz=n_cruz/n
print('la probabilidad aproximada en '+str(n)+' lanzamientos de sacar CARA es:', prom_cara)
print('la probabilidad aproximada en '+str(n)+' lanzamientos de sacar CRUZ es:', prom_cruz)
# Out:
# la probabilidad aproximada en 100 lanzamientos de sacar CARA es: 0.52
# la probabilidad aproximada en 100 lanzamientos de sacar CRUZ es: 0.48

# %%
#========== FORMA COMPACTA DE SIMULAR USANDO NUMPY===========
m=int(input('ingrese la cantidad de simulación o lanzamientos: '))
lanzamientos = np.random.randint(0, 2, m)
# Calcular las probabilidades

probabilidad_cara = np.sum(lanzamientos ==0 ) / len(lanzamientos)
probabilidad_sello = np.sum(lanzamientos== 1) / len(lanzamientos)

print(f"Probabilidad de cara: {probabilidad_cara:.2f}")
print(f"Probabilidad de sello: {probabilidad_sello:.2f}")
# Out:
# ingrese la cantidad de simulación o lanzamientos: 100
# Probabilidad de cara: 0.52
# Probabilidad de sello: 0.48

# %%
x=np.array(range(2))
y=np.array([probabilidad_cara, probabilidad_sello])

plt.bar(x,y)
plt.xlabel('Opción')
plt.ylabel('Frecuencia relativa')
plt.title('Histograma del lanzamiento de una moneda equilibrada')
plt.show()

# %% [markdown]
# # EJERCICIOS

# %% [markdown]
# ##***EJERCICIO 1***
#
# Simular el lanzamiento de un dado eqilibrado de 6 caras.
#
#
# *   Mostrar la probabilida aproximada de obtener el número 2, 3 y 5
# *   Graficar el histograma de las probabilidades

# %%
# Se le pide al usuario el numero de lanzamientos
n_de_lanzamientos=int(input('ingrese la cantidad de simulación o lanzamientos: '))

# Se realizan los lanzamientos
lanzamientos = np.random.randint(1, 7, n_de_lanzamientos)
#print(lanzamientos)

# Se calculan las probabilidades
probabilidad_de_2 = np.sum(lanzamientos == 2 ) / len(lanzamientos)
probabilidad_de_3 = np.sum(lanzamientos == 3 ) / len(lanzamientos)
probabilidad_de_5 = np.sum(lanzamientos == 5 ) / len(lanzamientos)

# Se muestran las probabilidades en pantalla
print(f"Probabilidad de sacar 2: {probabilidad_de_2:.2f}")
print(f"Probabilidad de sacar 3: {probabilidad_de_3:.2f}")
print(f"Probabilidad de sacar 5: {probabilidad_de_5:.2f}")
# Out:
# ingrese la cantidad de simulación o lanzamientos: 100
# Probabilidad de sacar 2: 0.20
# Probabilidad de sacar 3: 0.11
# Probabilidad de sacar 5: 0.18

# %%
# Se grafica el histograma
plt.hist(lanzamientos, bins=[1,2,3,4,5,6,7], align="left",edgecolor="Black",density=True)
plt.xlabel('Opción')
plt.ylabel('Probabilidad')
plt.title('Histograma del lanzamiento de un Dado equilibrado')
plt.show()

# %% [markdown]
# ## ***EJERCICIO 2***
#
# Simular el lanzamiento de un dado NO eqilibrado o cargado de 6 caras, de manera que las chances o probabilidades de salir 1 o 2 sean el doble de obtener otro resultado (3,4,5 o 6)
#
#
# *   Mostrar la probabilida aproximada de obtener el número 2, 3 y 5
# *   Graficar el histograma de las probabilidades

# %%
# Se le pide al usuario el numero de lanzamientos
n_de_lanzamientos=int(input('ingrese la cantidad de simulación o lanzamientos: '))

# Se realizan los lanzamientos
dado=[1,1,2,2,3,4,5,6]#Al tener 2 veces los numeros 1 y 2 tienen el doble de pibilidad de salir
indices = np.random.randint(0, 8, n_de_lanzamientos)
lanzamientos=np.array([dado[i] for i in indices])

# Se calculan las probabilidades
probabilidad_de_2 = np.sum(lanzamientos == 2 ) / len(lanzamientos)
probabilidad_de_3 = np.sum(lanzamientos == 3 ) / len(lanzamientos)
probabilidad_de_5 = np.sum(lanzamientos == 5 ) / len(lanzamientos)

# Se muestran las probabilidades en pantalla
print(f"Probabilidad de sacar 2: {probabilidad_de_2:.2f}")
print(f"Probabilidad de sacar 3: {probabilidad_de_3:.2f}")
print(f"Probabilidad de sacar 5: {probabilidad_de_5:.2f}")
# Out:
# ingrese la cantidad de simulación o lanzamientos: 100
# Probabilidad de sacar 2: 0.20
# Probabilidad de sacar 3: 0.11
# Probabilidad de sacar 5: 0.22

# %%
# Se grafica el histograma
plt.hist(lanzamientos, bins=[1,2,3,4,5,6,7], align="left",edgecolor="Black",density=True)
plt.xlabel('Opción')
plt.ylabel('Probabilidad')
plt.title('Histograma del lanzamiento de un Dado equilibrado')
plt.show()

# %% [markdown]
# ## EJERCICIO 3
#
#  Realizar la simulación del juego {piedra,papel , tijera} donde el resultado de esta simulación deberá ser lo que mi oponente elije. No debe considerarse la simulación de mi elección.
#
#
#
# *   Calcular la probailidad aproximada que mi oponente elija, 'piedra', 'papel', o 'tijera', en N jugadas.
# *   Realizar un grafico de barra mostrando estas probabilidad. Concluir algo sobre las probabilidades de estos resultados, cuando el número de jugadas se incrementa bastante.

# %%
# Se le pide al usuario el numero de lanzamientos
n=int(input('ingrese la cantidad de simulación o lanzamientos: '))

# Se realizan los lanzamientos
opciones = ["Piedra", "Papel", "Tijeras"]
indices = np.random.randint(0, 3, n)
lanzamientos = np.array([opciones[indice] for indice in indices])

# Se calculan las probabilidades
probabilidad_de_piedra = np.sum(lanzamientos == "Piedra" ) / len(lanzamientos)
probabilidad_de_papel = np.sum(lanzamientos == "Papel" ) / len(lanzamientos)
probabilidad_de_tijeras = np.sum(lanzamientos == "Tijeras" ) / len(lanzamientos)

# Se muestran las probabilidades en pantalla
print(f"Probabilidad de sacar Piedra: {probabilidad_de_piedra:.2f}")
print(f"Probabilidad de sacar Papel: {probabilidad_de_papel:.2f}")
print(f"Probabilidad de sacar Tijeras: {probabilidad_de_tijeras:.2f}")
# Out:
# ingrese la cantidad de simulación o lanzamientos: 100000
# Probabilidad de sacar Piedra: 0.33
# Probabilidad de sacar Papel: 0.33
# Probabilidad de sacar Tijeras: 0.33

# %%
#Se grafica el grafico de barras
x=opciones
y=[probabilidad_de_piedra, probabilidad_de_papel, probabilidad_de_tijeras]

plt.bar(x,y)
plt.ylabel('Frecuencia relativa')
plt.title(f'Probabilidades de Piedra, Papel o Tijeras en {n} lanzamientos')
plt.show()

# %% [markdown]
# #### Conclución
# Como se obserba en la simulacion las probabilidades de que cada opcion salga aleatoriamente son las mismas para cada opcion al  acercarse al +∞.

# %% [markdown]
# ## EJERCICIO 4
#
# Dada la base de datos de ventas diarias durante una semana, de un negocio con 4 productos.- VER EJERCICIO PARTE 2 PRACTICO N 2- Realizar el siguiente análisis de datos para poder obtener información y planificar una estrategia de ventas.
#
#
# 1.   Calcular la media en la ventas por cada producto y la mediana. Plotear estos nuevos datos en un gráfico de barra.
# 2.    Calcular la media en la ventas por DÍA y la mediana. Plotear estos nuevos datos en un gráfico de TRAZO DE LINEAS.
# 3.   Realizar una conclusión en función las graficas y sugerir al menos 5 estrategias de venta o inversión de manera de potenciar este negocio.
# 4.   Calcular el desvio estandar de los datos por cada producto y concluir para cada producto como es su rango de variabilidad en las ventas de los mismos.Plotear los datos de ventas de la semana de los productos con mayor y menor desvio estandar y evidenciar la variabilidad indicada en el parametro *'DESVIO ESTANDAR'*

# %%
import pandas as pd
# Se importa el Data Frame
df = pd.read_csv("./ventasDiarias.csv") # SRC=https://drive.google.com/file/d/1cW7cqwtIU5WXXP7jQNJJrp2Zfb0_egSW
df.drop("Unnamed: 0", axis=1, inplace=True)
# Se calcula media y mediana por producto
y_media=df.mean(axis=1)
y_mediana=df.median(axis=1)
# Se crean  las categorias del eje x
x=["prod"+str(i+1) for (i,m) in enumerate(df.index)]
# Se genera el grafico de barras
plt.bar(x,y_media,align="edge",width=-.3, label="Media")
plt.bar(x,y_mediana,align="edge", width=.3, label="Mediana")
plt.xlabel('Productos')
plt.ylabel('Ventas')
plt.title('Ventas promedio por producto')
plt.legend()
plt.grid()
plt.show()

# %%
# Se calcula media y mediana por dia
y_media=df.mean()
y_mediana=df.median()
# Se crean  las categorias del eje x
x=[dia for dia in df.columns]
# Se genera el grafico de barras
plt.plot(x,y_media, label="Media")
plt.plot(x,y_mediana,"--", label="Mediana")
plt.xlabel('Dias')
plt.ylabel('Ventas')
plt.title('Ventas en promedio por dia')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ###Conclusion
# Como muestranlos graficos  se puede concluir que los días Miercoles y Jueves  son  los mas productivos mientras que no así los dias Viernes y Sabados. Tambien, se puede ver que el producto mas vendido es el producto 4 mientras que el menos vendido es el 2.  Y los dias Jueves, Viernes y Sabados tienen gran diferencia entre media y mediana. Por lo que se recomiendan las siguientes estrategias:
#
# >1.  Tener un  gran stock del producto 4.
#
# >2.  No tener  mucho stock  del producto 2.
#
# >3.  Hacer promociones los Viernes y Sabados para aumentar las ventas esos días.
#
# >4.  Reforzar la cantidad de personal los días Miercoles y Jueves para mejorar la atencion.
#
# >5.  Buscar patrones que expliquen la diferencia entre media y mediana los dias Jueves, Viernes y Sabados.
#
# ---

# %%
desvios_estandar = df.std(axis=1)
for (i,std) in enumerate(desvios_estandar):
  print(f"Desviacion estandar del producto {i+1}: {std}")
# Out:
# Desviacion estandar del producto 1: 4.932882862316247
# Desviacion estandar del producto 2: 3.946064947695181
# Desviacion estandar del producto 3: 3.6839419880650364
# Desviacion estandar del producto 4: 2.690370836538197

# %% [markdown]
# La variabilidad de las ventas por producto en la  semana es baja y no cambia mucho por producto.

# %%
producto_1 = [df[:1][col] for col in df[:1]]
producto_4 = [df[3:4][col] for col in df[3:4]]
media_prod_1 = df.mean(axis=1)[0]
media_prod_4 = df.mean(axis=1)[3]
std_prod_1 = desvios_estandar[0]
std_prod_4 = desvios_estandar[3]
plt.plot(x,producto_1,label="Producto 1")
plt.fill_between(x,media_prod_1+std_prod_1, media_prod_1-std_prod_1, alpha=0.2, label="std prod 1")
plt.plot(x,producto_4,label="Producto 4")
plt.fill_between(x,media_prod_4+std_prod_4, media_prod_4-std_prod_4,alpha=0.2, label="std prod 4")
plt.xlabel('Dias')
plt.ylabel('Ventas')
plt.title('Ventas en promedio por dia')
plt.legend(bbox_to_anchor=(1, -0.3), loc='lower left')
plt.grid()
plt.show()

# %% [markdown]
# ## EJERCICIO 5
#
# Solicitar al usuario que ingrese la cantidad N de datos a cargar. Luego generar de manera aleatoria los siguientes datos:
#
# * SEXO= 'MASCULINO', 'FEMENINO','NO ESPECIFICA'
# * EDAD= entre 28 y 60 años
# * ALTURA= entre un rango de 165.0 mts hasta 210 mts
# * PESO= entre un rango de 50  y 110 kg
# * HORAS DE DESCANSO diario= un número decimal
# * HORAS DE TRABAJO/ ESTUDIO diario= un número decimal
# * HORAS DE EJERCICIOS diario= un número decimal
#
# REalizar las siguientes indicaciones y extraer concluisiones sobre la información y la pooblación muestreada.
#
# 1.   Generar un array de dimensión 2 (matriz), con todos los datos ordenados, permitiendo visualizarlos como tabla.
# 2.   Suponiendo que la distribución de probabilidad de los datos muestrados de las N personas, se distribuyen en forma NORMAL. Encontrar la media en los datos de altura, peso, y horas de descanso, trabajo y ejercicios.
# 3.  Graficar la muestra o distribución de los datos  de pesos , y alturas en graficas separadas. Indicar el grado de variabilidad de sus datos
# 4.  Plotear de manera conjunta y encontrar si presentan correlación los datos de peso vs altura,
# 5. Plotear de manera conjunta los datos de horas de descanso, estudio y ejercicio

# %%
import numpy as np
import pandas as  pd
n= int(input("Ingrese la cantidad de datos a generar: "))
sexo_opc=['MASCULINO','FEMENINO','NO ESPECIFICA']
def generar_dato():
  sexo = sexo_opc[np.random.randint(0, 3, 1)[0]]
  edad = np.random.randint(28, 61, 1)[0]
  altura =  np.random.randint(165, 211, 1)[0]
  peso = np.random.randint(50, 111, 1)[0]
  hs_descanso = np.random.randint(400, 1200, 1)[0]/100
  hs_trabajo =  np.random.randint(400, 1200, 1)[0]/100
  hs_ejercicio = np.random.randint(100, 200, 1)[0]/100
  return [sexo, edad, altura,peso,hs_descanso,hs_trabajo,hs_ejercicio]
rows=[generar_dato()for i in range(n)]
colums=[]
df=pd.DataFrame(rows,columns=["Sexo","Edad","Altura","Peso","Hs de Descanso", "Hs de Trabajo/Estudio", "Hs de Ejercicio"])
df.head()
# Out:
# Ingrese la cantidad de datos a generar: 1000
#             Sexo  Edad  Altura  Peso  Hs de Descanso  Hs de Trabajo/Estudio  \
# 0  NO ESPECIFICA    38     204    91           11.19                   7.79
# 1      MASCULINO    49     206    83            8.94                   7.12
# 2      MASCULINO    53     203    98            9.97                   7.59
# 3      MASCULINO    44     177    86           11.39                   7.99
# 4      MASCULINO    46     182    93            7.48                   4.21
#
#    Hs de Ejercicio
# 0             1.87
# 1             1.11
# 2             1.62
# 3             1.83
# 4             1.84

# %%
df[["Altura", "Peso", "Hs de Descanso", "Hs de Trabajo/Estudio" , "Hs de Ejercicio"]].mean()
# Out:
# Altura                   187.86000
# Peso                      80.57000
# Hs de Descanso             7.92267
# Hs de Trabajo/Estudio      8.04428
# Hs de Ejercicio            1.49267
# dtype: float64

# %%
import matplotlib.pyplot as plt
fig, (ax1,ax2) = plt.subplots(2,1,figsize=(10,12))
ax1.hist(df["Peso"], bins=100,)
ax1.set_title('Distribucion de peso en una muestra aleatoria de 1000 personas')
ax1.set_xlabel("valores")
ax1.set_ylabel("cantidad de datos")
ax2.hist(df["Altura"], bins=100)
ax2.set_title('Distribucion de peso en una muestra aleatoria de 1000 personas')
ax2.set_xlabel("valores")
ax2.set_ylabel("cantidad de datos")
plt.show()

# %%
x=df["Peso"]
y=df["Altura"]
plt.scatter(x, y)
plt.title("Relacion entre peso y altura")
plt.xlabel("Peso")
plt.ylabel("Altura")
plt.show()

# %%
plt.hist(df["Hs de Ejercicio"], bins=100,label="Hs de Ejercicio", alpha=0.8)
plt.hist(df["Hs de Trabajo/Estudio"], bins=100,label="Hs de Trabajo/Estudio")
plt.hist(df["Hs de Descanso"], bins=100,label="Hs de Descanso", alpha=0.5)
plt.xlabel("Horas")
plt.ylabel("Cantidad de casos/10")
plt.legend()
plt.show()

# %% [markdown]
# ## EJERCICIO 6
#
# Se realiza una encuesta a N usuario donde se registran los siguientes datos.
#
# ['DNI','GASTOS MENSUALES DE HOGAR','INGRESOS MENSUALES POR HOGAR', 'CANTIDAD DE MIEMBROS QUE VIVEN POR HOGAR','GASTO MENSUAL EN LINEA TELEFÓNICA', 'GASTO MENSUAL POR PAGO DE INTERNET' ]
#
# Realizar la simulación de la carga de datos utilizando la siguiente información adicional:
#
#
# 1.   El 70 % de los encuestados son jóvenes entre 15 y 21 años, el 10% son mayores de 60 años. Sugerencia, utilizar esto para generar los DNI
# 2.   Los encuestados son de la provincia de Cordoba. Además el 80 % de la población de esa provincia tiene un grupo familiar de 5 personas. Con ingresos mensuales promedio de $258.000
# 2.   Cerca del 80 % de los encuestados Gastan el 90% de sus ingresos, el resto gasta el 80% de sus ingresos.Ayuda, para simular la cantidad de miembros utilizar la distribución normal.
# 3.  Del gasto Total por hogar se sabe que se abona un 15 % en telefonía y un 7.8% en servicio de internet.
#
# Con la información proporcionada, realizar la simulación de las encuestas de 100 y 1000 personas.
#
# *   Calcular el valor medio y desvio estandar de los gastos mensuales, ingresos mensuales y pagos de servicios.
# *   Plotear los datos de los ingesos , y gastos en gráficos de barra por separado y evidenciar la media y desvio estandar.
# *   Calcular la proporciona de jóvenes menores a 21 encuestados. Mostrar sus datos de grupos familiares, gastos en servicios de internet y telefonía. Concluir algo en base a esta información.
# *   Realizar un histograma con el dato del grupo familiar, y concluir algo acerca de la distribución de probabilidad.
